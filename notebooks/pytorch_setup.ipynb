# %%
import torch
# Out:
# Caching the list of root modules, please wait!
# (This will only be done once - type '%rehashx' to reset cache!)
# /Users/mac-SAITSI15/Desktop/build-llm-from-scratch/.venv/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:368: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
torch.backends.mps.is_available()
# Out:
# True

# %% [markdown]
# ## data types

# %%
tensor1d = torch.tensor([1,2,3])

print(tensor1d.dtype)
# Out:
# torch.int64

# %%
torch.tensor([1.0,2.0,3.0]).dtype
# Out:
# torch.float32

# %%
floatvec = tensor1d.to(torch.float32)
print(floatvec.dtype)
# Out:
# torch.float32
